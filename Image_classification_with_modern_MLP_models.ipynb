# %%
pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 41.2 MB/s eta 0:00:00
# Collecting typeguard<3.0.0,>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
num_classes = 100
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 13s 0us/step
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %%
weight_decay = 0.0001
batch_size = 128
num_epochs = 50
dropout_rate = 0.2
image_size = 64  # We'll resize input images to this size.
patch_size = 8  # Size of the patches to be extracted from the input images.
num_patches = (image_size // patch_size) ** 2  # Size of the data array.
embedding_dim = 256  # Number of hidden units.
num_blocks = 4  # Number of blocks.

print(f"Image size: {image_size} X {image_size} = {image_size ** 2}")
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
print(f"Elements per patch (3 channels): {(patch_size ** 2) * 3}")
# Out:
# Image size: 64 X 64 = 4096
# Patch size: 8 X 8 = 64
# Patches per image: 64
# Elements per patch (3 channels): 192

# %%
def build_classifier(blocks, positional_encoding=False):
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size, num_patches)(augmented)
    # Encode patches to generate a [batch_size, num_patches, embedding_dim] tensor.
    x = layers.Dense(units=embedding_dim)(patches)
    if positional_encoding:
        positions = tf.range(start=0, limit=num_patches, delta=1)
        position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=embedding_dim
        )(positions)
        x = x + position_embedding
    # Process x using the module blocks.
    x = blocks(x)
    # Apply global average pooling to generate a [batch_size, embedding_dim] representation tensor.
    representation = layers.GlobalAveragePooling1D()(x)
    # Apply dropout.
    representation = layers.Dropout(rate=dropout_rate)(representation)
    # Compute logits outputs.
    logits = layers.Dense(num_classes)(representation)
    # Create the Keras model.
    return keras.Model(inputs=inputs, outputs=logits)

# %%
def run_experiment(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="acc"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top5-acc"),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Create an early stopping callback.
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[early_stopping, reduce_lr],
    )

    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    # Return history to plot learning curves.
    return history

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size, num_patches):
        super().__init__()
        self.patch_size = patch_size
        self.num_patches = num_patches

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, self.num_patches, patch_dims])
        return patches

# %%
class MLPMixerLayer(layers.Layer):
    def __init__(self, num_patches, hidden_units, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)

        self.mlp1 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=num_patches),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.mlp2 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=embedding_dim),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.normalize = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        # Apply layer normalization.
        x = self.normalize(inputs)
        # Transpose inputs from [num_batches, num_patches, hidden_units] to [num_batches, hidden_units, num_patches].
        x_channels = tf.linalg.matrix_transpose(x)
        # Apply mlp1 on each channel independently.
        mlp1_outputs = self.mlp1(x_channels)
        # Transpose mlp1_outputs from [num_batches, hidden_dim, num_patches] to [num_batches, num_patches, hidden_units].
        mlp1_outputs = tf.linalg.matrix_transpose(mlp1_outputs)
        # Add skip connection.
        x = mlp1_outputs + inputs
        # Apply layer normalization.
        x_patches = self.normalize(x)
        # Apply mlp2 on each patch independtenly.
        mlp2_outputs = self.mlp2(x_patches)
        # Add skip connection.
        x = x + mlp2_outputs
        return x

# %%
mlpmixer_blocks = keras.Sequential(
    [MLPMixerLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
learning_rate = 0.005
mlpmixer_classifier = build_classifier(mlpmixer_blocks)
history = run_experiment(mlpmixer_classifier)
# Out:
# Epoch 1/50
# 352/352 [==============================] - 31s 62ms/step - loss: 3.8538 - acc: 0.1128 - top5-acc: 0.3228 - val_loss: 3.5332 - val_acc: 0.1760 - val_top5-acc: 0.4318 - lr: 0.0050
# Epoch 2/50
# 352/352 [==============================] - 19s 54ms/step - loss: 3.3672 - acc: 0.1904 - top5-acc: 0.4630 - val_loss: 3.1623 - val_acc: 0.2346 - val_top5-acc: 0.5244 - lr: 0.0050
# Epoch 3/50
# 352/352 [==============================] - 19s 53ms/step - loss: 3.1858 - acc: 0.2254 - top5-acc: 0.5102 - val_loss: 3.0895 - val_acc: 0.2618 - val_top5-acc: 0.5584 - lr: 0.0050
# Epoch 4/50
# 352/352 [==============================] - 19s 53ms/step - loss: 3.0129 - acc: 0.2553 - top5-acc: 0.5570 - val_loss: 2.9647 - val_acc: 0.2852 - val_top5-acc: 0.5836 - lr: 0.0050
# Epoch 5/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.9002 - acc: 0.2796 - top5-acc: 0.5850 - val_loss: 2.9526 - val_acc: 0.2868 - val_top5-acc: 0.5818 - lr: 0.0050
# Epoch 6/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.8096 - acc: 0.2943 - top5-acc: 0.6073 - val_loss: 2.7067 - val_acc: 0.3230 - val_top5-acc: 0.6340 - lr: 0.0050
# Epoch 7/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.7380 - acc: 0.3076 - top5-acc: 0.6222 - val_loss: 2.6937 - val_acc: 0.3256 - val_top5-acc: 0.6442 - lr: 0.0050
# Epoch 8/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.6909 - acc: 0.3174 - top5-acc: 0.6344 - val_loss: 2.7095 - val_acc: 0.3258 - val_top5-acc: 0.6442 - lr: 0.0050
# Epoch 9/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.6449 - acc: 0.3273 - top5-acc: 0.6425 - val_loss: 2.7142 - val_acc: 0.3362 - val_top5-acc: 0.6438 - lr: 0.0050
# Epoch 10/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.6156 - acc: 0.3358 - top5-acc: 0.6508 - val_loss: 2.6491 - val_acc: 0.3486 - val_top5-acc: 0.6522 - lr: 0.0050
# Epoch 11/50
# 352/352 [==============================] - 18s 53ms/step - loss: 2.5719 - acc: 0.3432 - top5-acc: 0.6616 - val_loss: 2.5666 - val_acc: 0.3592 - val_top5-acc: 0.6748 - lr: 0.0050
# Epoch 12/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.5368 - acc: 0.3476 - top5-acc: 0.6662 - val_loss: 2.4977 - val_acc: 0.3688 - val_top5-acc: 0.6900 - lr: 0.0050
# Epoch 13/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.5190 - acc: 0.3528 - top5-acc: 0.6723 - val_loss: 2.6102 - val_acc: 0.3598 - val_top5-acc: 0.6700 - lr: 0.0050
# Epoch 14/50
# 352/352 [==============================] - 19s 55ms/step - loss: 2.4643 - acc: 0.3640 - top5-acc: 0.6833 - val_loss: 2.4437 - val_acc: 0.3778 - val_top5-acc: 0.6928 - lr: 0.0050
# Epoch 15/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.4238 - acc: 0.3731 - top5-acc: 0.6928 - val_loss: 2.4355 - val_acc: 0.3752 - val_top5-acc: 0.7008 - lr: 0.0050
# Epoch 16/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.4133 - acc: 0.3764 - top5-acc: 0.6954 - val_loss: 2.4180 - val_acc: 0.3892 - val_top5-acc: 0.7094 - lr: 0.0050
# Epoch 17/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.3877 - acc: 0.3806 - top5-acc: 0.6998 - val_loss: 2.4119 - val_acc: 0.3986 - val_top5-acc: 0.7092 - lr: 0.0050
# Epoch 18/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.3705 - acc: 0.3825 - top5-acc: 0.7052 - val_loss: 2.4081 - val_acc: 0.3998 - val_top5-acc: 0.7086 - lr: 0.0050
# Epoch 19/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.3418 - acc: 0.3894 - top5-acc: 0.7082 - val_loss: 2.3853 - val_acc: 0.3998 - val_top5-acc: 0.7104 - lr: 0.0050
# Epoch 20/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.3206 - acc: 0.3934 - top5-acc: 0.7157 - val_loss: 2.3946 - val_acc: 0.4052 - val_top5-acc: 0.7080 - lr: 0.0050
# Epoch 21/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.2996 - acc: 0.3989 - top5-acc: 0.7181 - val_loss: 2.3719 - val_acc: 0.4028 - val_top5-acc: 0.7188 - lr: 0.0050
# Epoch 22/50
# 352/352 [==============================] - 19s 55ms/step - loss: 2.2825 - acc: 0.4028 - top5-acc: 0.7236 - val_loss: 2.3525 - val_acc: 0.4062 - val_top5-acc: 0.7122 - lr: 0.0050
# Epoch 23/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.2649 - acc: 0.4030 - top5-acc: 0.7256 - val_loss: 2.3628 - val_acc: 0.4152 - val_top5-acc: 0.7242 - lr: 0.0050
# Epoch 24/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.2400 - acc: 0.4104 - top5-acc: 0.7301 - val_loss: 2.3088 - val_acc: 0.4228 - val_top5-acc: 0.7292 - lr: 0.0050
# Epoch 25/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.2321 - acc: 0.4107 - top5-acc: 0.7316 - val_loss: 2.3381 - val_acc: 0.4146 - val_top5-acc: 0.7282 - lr: 0.0050
# Epoch 26/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.2175 - acc: 0.4134 - top5-acc: 0.7334 - val_loss: 2.3121 - val_acc: 0.4112 - val_top5-acc: 0.7256 - lr: 0.0050
# Epoch 27/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.2142 - acc: 0.4176 - top5-acc: 0.7330 - val_loss: 2.3411 - val_acc: 0.4158 - val_top5-acc: 0.7206 - lr: 0.0050
# Epoch 28/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.1965 - acc: 0.4197 - top5-acc: 0.7381 - val_loss: 2.3651 - val_acc: 0.4118 - val_top5-acc: 0.7252 - lr: 0.0050
# Epoch 29/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.1808 - acc: 0.4214 - top5-acc: 0.7436 - val_loss: 2.3192 - val_acc: 0.4094 - val_top5-acc: 0.7334 - lr: 0.0050
# Epoch 30/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.9628 - acc: 0.4722 - top5-acc: 0.7811 - val_loss: 2.1002 - val_acc: 0.4576 - val_top5-acc: 0.7670 - lr: 0.0025
# Epoch 31/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.9041 - acc: 0.4863 - top5-acc: 0.7920 - val_loss: 2.0882 - val_acc: 0.4610 - val_top5-acc: 0.7696 - lr: 0.0025
# Epoch 32/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.8916 - acc: 0.4874 - top5-acc: 0.7949 - val_loss: 2.1193 - val_acc: 0.4536 - val_top5-acc: 0.7632 - lr: 0.0025
# Epoch 33/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.8819 - acc: 0.4882 - top5-acc: 0.7982 - val_loss: 2.0716 - val_acc: 0.4618 - val_top5-acc: 0.7722 - lr: 0.0025
# Epoch 34/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.8726 - acc: 0.4891 - top5-acc: 0.7994 - val_loss: 2.1053 - val_acc: 0.4528 - val_top5-acc: 0.7634 - lr: 0.0025
# Epoch 35/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.8574 - acc: 0.4926 - top5-acc: 0.8033 - val_loss: 2.0671 - val_acc: 0.4754 - val_top5-acc: 0.7708 - lr: 0.0025
# Epoch 36/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.8463 - acc: 0.4955 - top5-acc: 0.8048 - val_loss: 2.0959 - val_acc: 0.4590 - val_top5-acc: 0.7736 - lr: 0.0025
# Epoch 37/50
# 352/352 [==============================] - 19s 55ms/step - loss: 1.8430 - acc: 0.4969 - top5-acc: 0.8037 - val_loss: 2.0638 - val_acc: 0.4662 - val_top5-acc: 0.7770 - lr: 0.0025
# Epoch 38/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.8316 - acc: 0.4996 - top5-acc: 0.8052 - val_loss: 2.0450 - val_acc: 0.4738 - val_top5-acc: 0.7730 - lr: 0.0025
# Epoch 39/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.8319 - acc: 0.4997 - top5-acc: 0.8079 - val_loss: 2.1183 - val_acc: 0.4560 - val_top5-acc: 0.7670 - lr: 0.0025
# Epoch 40/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.8232 - acc: 0.5012 - top5-acc: 0.8068 - val_loss: 2.0292 - val_acc: 0.4656 - val_top5-acc: 0.7760 - lr: 0.0025
# Epoch 41/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.8105 - acc: 0.5035 - top5-acc: 0.8101 - val_loss: 2.0539 - val_acc: 0.4636 - val_top5-acc: 0.7760 - lr: 0.0025
# Epoch 42/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.8055 - acc: 0.5068 - top5-acc: 0.8102 - val_loss: 2.0930 - val_acc: 0.4642 - val_top5-acc: 0.7696 - lr: 0.0025
# Epoch 43/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.7957 - acc: 0.5083 - top5-acc: 0.8116 - val_loss: 2.0361 - val_acc: 0.4756 - val_top5-acc: 0.7810 - lr: 0.0025
# Epoch 44/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.7965 - acc: 0.5086 - top5-acc: 0.8100 - val_loss: 2.0618 - val_acc: 0.4704 - val_top5-acc: 0.7712 - lr: 0.0025
# Epoch 45/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.7839 - acc: 0.5110 - top5-acc: 0.8166 - val_loss: 2.0993 - val_acc: 0.4560 - val_top5-acc: 0.7738 - lr: 0.0025
# Epoch 46/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.6509 - acc: 0.5394 - top5-acc: 0.8372 - val_loss: 1.9471 - val_acc: 0.4924 - val_top5-acc: 0.7898 - lr: 0.0012
# Epoch 47/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.6170 - acc: 0.5503 - top5-acc: 0.8428 - val_loss: 1.9410 - val_acc: 0.4946 - val_top5-acc: 0.7944 - lr: 0.0012
# Epoch 48/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.6124 - acc: 0.5516 - top5-acc: 0.8436 - val_loss: 1.9985 - val_acc: 0.4822 - val_top5-acc: 0.7884 - lr: 0.0012
# Epoch 49/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.6064 - acc: 0.5524 - top5-acc: 0.8441 - val_loss: 1.9565 - val_acc: 0.4946 - val_top5-acc: 0.7908 - lr: 0.0012
# Epoch 50/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.6080 - acc: 0.5546 - top5-acc: 0.8439 - val_loss: 1.9421 - val_acc: 0.4908 - val_top5-acc: 0.7976 - lr: 0.0012
# 313/313 [==============================] - 4s 14ms/step - loss: 1.9108 - acc: 0.5057 - top5-acc: 0.7936
# Test accuracy: 50.57%
# Test top 5 accuracy: 79.36%

# %%
class FNetLayer(layers.Layer):
    def __init__(self, num_patches, embedding_dim, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)

        self.ffn = keras.Sequential(
            [
                layers.Dense(units=embedding_dim),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
                layers.Dense(units=embedding_dim),
            ]
        )

        self.normalize1 = layers.LayerNormalization(epsilon=1e-6)
        self.normalize2 = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        # Apply fourier transformations.
        x = tf.cast(
            tf.signal.fft2d(tf.cast(inputs, dtype=tf.dtypes.complex64)),
            dtype=tf.dtypes.float32,
        )
        # Add skip connection.
        x = x + inputs
        # Apply layer normalization.
        x = self.normalize1(x)
        # Apply Feedfowrad network.
        x_ffn = self.ffn(x)
        # Add skip connection.
        x = x + x_ffn
        # Apply layer normalization.
        return self.normalize2(x)

# %%
fnet_blocks = keras.Sequential(
    [FNetLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
learning_rate = 0.001
fnet_classifier = build_classifier(fnet_blocks, positional_encoding=True)
history = run_experiment(fnet_classifier)
# Out:
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# Epoch 1/50
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 351/352 [============================>.] - ETA: 0s - loss: 4.1316 - acc: 0.0725 - top5-acc: 0.2301
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 352/352 [==============================] - 24s 56ms/step - loss: 4.1312 - acc: 0.0726 - top5-acc: 0.2302 - val_loss: 3.9384 - val_acc: 0.1020 - val_top5-acc: 0.2980 - lr: 0.0010
# Epoch 2/50
# 352/352 [==============================] - 19s 53ms/step - loss: 3.7282 - acc: 0.1276 - top5-acc: 0.3500 - val_loss: 3.5339 - val_acc: 0.1632 - val_top5-acc: 0.4104 - lr: 0.0010
# Epoch 3/50
# 352/352 [==============================] - 18s 52ms/step - loss: 3.4848 - acc: 0.1673 - top5-acc: 0.4219 - val_loss: 3.2931 - val_acc: 0.2030 - val_top5-acc: 0.4724 - lr: 0.0010
# Epoch 4/50
# 352/352 [==============================] - 18s 51ms/step - loss: 3.2908 - acc: 0.2048 - top5-acc: 0.4752 - val_loss: 3.1480 - val_acc: 0.2250 - val_top5-acc: 0.5234 - lr: 0.0010
# Epoch 5/50
# 352/352 [==============================] - 18s 52ms/step - loss: 3.1513 - acc: 0.2262 - top5-acc: 0.5172 - val_loss: 3.0809 - val_acc: 0.2466 - val_top5-acc: 0.5302 - lr: 0.0010
# Epoch 6/50
# 352/352 [==============================] - 18s 52ms/step - loss: 3.0226 - acc: 0.2505 - top5-acc: 0.5470 - val_loss: 2.9059 - val_acc: 0.2738 - val_top5-acc: 0.5744 - lr: 0.0010
# Epoch 7/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.9279 - acc: 0.2680 - top5-acc: 0.5690 - val_loss: 2.8324 - val_acc: 0.2934 - val_top5-acc: 0.5908 - lr: 0.0010
# Epoch 8/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.8401 - acc: 0.2843 - top5-acc: 0.5950 - val_loss: 2.7674 - val_acc: 0.2988 - val_top5-acc: 0.6112 - lr: 0.0010
# Epoch 9/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.7707 - acc: 0.2982 - top5-acc: 0.6097 - val_loss: 2.7036 - val_acc: 0.3082 - val_top5-acc: 0.6304 - lr: 0.0010
# Epoch 10/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.7107 - acc: 0.3086 - top5-acc: 0.6247 - val_loss: 2.6947 - val_acc: 0.3158 - val_top5-acc: 0.6290 - lr: 0.0010
# Epoch 11/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.6549 - acc: 0.3237 - top5-acc: 0.6374 - val_loss: 2.6092 - val_acc: 0.3424 - val_top5-acc: 0.6442 - lr: 0.0010
# Epoch 12/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.6186 - acc: 0.3274 - top5-acc: 0.6449 - val_loss: 2.5777 - val_acc: 0.3406 - val_top5-acc: 0.6524 - lr: 0.0010
# Epoch 13/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.5655 - acc: 0.3388 - top5-acc: 0.6564 - val_loss: 2.5096 - val_acc: 0.3596 - val_top5-acc: 0.6678 - lr: 0.0010
# Epoch 14/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.5195 - acc: 0.3504 - top5-acc: 0.6678 - val_loss: 2.5317 - val_acc: 0.3598 - val_top5-acc: 0.6714 - lr: 0.0010
# Epoch 15/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.4898 - acc: 0.3550 - top5-acc: 0.6756 - val_loss: 2.4762 - val_acc: 0.3650 - val_top5-acc: 0.6644 - lr: 0.0010
# Epoch 16/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.4611 - acc: 0.3621 - top5-acc: 0.6820 - val_loss: 2.4696 - val_acc: 0.3626 - val_top5-acc: 0.6756 - lr: 0.0010
# Epoch 17/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.4265 - acc: 0.3678 - top5-acc: 0.6878 - val_loss: 2.5001 - val_acc: 0.3610 - val_top5-acc: 0.6666 - lr: 0.0010
# Epoch 18/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.4012 - acc: 0.3744 - top5-acc: 0.6941 - val_loss: 2.4686 - val_acc: 0.3670 - val_top5-acc: 0.6706 - lr: 0.0010
# Epoch 19/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.3679 - acc: 0.3817 - top5-acc: 0.7023 - val_loss: 2.4357 - val_acc: 0.3750 - val_top5-acc: 0.6838 - lr: 0.0010
# Epoch 20/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.3442 - acc: 0.3870 - top5-acc: 0.7059 - val_loss: 2.4052 - val_acc: 0.3848 - val_top5-acc: 0.6888 - lr: 0.0010
# Epoch 21/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.3212 - acc: 0.3943 - top5-acc: 0.7112 - val_loss: 2.3691 - val_acc: 0.3950 - val_top5-acc: 0.6980 - lr: 0.0010
# Epoch 22/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.3058 - acc: 0.3957 - top5-acc: 0.7122 - val_loss: 2.3642 - val_acc: 0.3934 - val_top5-acc: 0.6964 - lr: 0.0010
# Epoch 23/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.2839 - acc: 0.3993 - top5-acc: 0.7184 - val_loss: 2.3650 - val_acc: 0.3874 - val_top5-acc: 0.6952 - lr: 0.0010
# Epoch 24/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.2593 - acc: 0.4039 - top5-acc: 0.7226 - val_loss: 2.3891 - val_acc: 0.3870 - val_top5-acc: 0.6950 - lr: 0.0010
# Epoch 25/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.2384 - acc: 0.4101 - top5-acc: 0.7286 - val_loss: 2.3152 - val_acc: 0.3966 - val_top5-acc: 0.7100 - lr: 0.0010
# Epoch 26/50
# 352/352 [==============================] - 19s 55ms/step - loss: 2.2235 - acc: 0.4150 - top5-acc: 0.7303 - val_loss: 2.2737 - val_acc: 0.4078 - val_top5-acc: 0.7158 - lr: 0.0010
# Epoch 27/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.2117 - acc: 0.4154 - top5-acc: 0.7347 - val_loss: 2.3089 - val_acc: 0.4002 - val_top5-acc: 0.7094 - lr: 0.0010
# Epoch 28/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.1903 - acc: 0.4219 - top5-acc: 0.7357 - val_loss: 2.2815 - val_acc: 0.4138 - val_top5-acc: 0.7174 - lr: 0.0010
# Epoch 29/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.1726 - acc: 0.4231 - top5-acc: 0.7411 - val_loss: 2.2584 - val_acc: 0.4176 - val_top5-acc: 0.7240 - lr: 0.0010
# Epoch 30/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.1674 - acc: 0.4263 - top5-acc: 0.7419 - val_loss: 2.2549 - val_acc: 0.4170 - val_top5-acc: 0.7194 - lr: 0.0010
# Epoch 31/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.1396 - acc: 0.4337 - top5-acc: 0.7470 - val_loss: 2.2560 - val_acc: 0.4172 - val_top5-acc: 0.7184 - lr: 0.0010
# Epoch 32/50
# 352/352 [==============================] - 18s 53ms/step - loss: 2.1267 - acc: 0.4317 - top5-acc: 0.7506 - val_loss: 2.2944 - val_acc: 0.4072 - val_top5-acc: 0.7088 - lr: 0.0010
# Epoch 33/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.1128 - acc: 0.4370 - top5-acc: 0.7536 - val_loss: 2.2751 - val_acc: 0.4172 - val_top5-acc: 0.7198 - lr: 0.0010
# Epoch 34/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.1036 - acc: 0.4375 - top5-acc: 0.7547 - val_loss: 2.2958 - val_acc: 0.4060 - val_top5-acc: 0.7172 - lr: 0.0010
# Epoch 35/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.0930 - acc: 0.4433 - top5-acc: 0.7594 - val_loss: 2.2459 - val_acc: 0.4160 - val_top5-acc: 0.7222 - lr: 0.0010
# Epoch 36/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.0762 - acc: 0.4438 - top5-acc: 0.7619 - val_loss: 2.2139 - val_acc: 0.4188 - val_top5-acc: 0.7334 - lr: 0.0010
# Epoch 37/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.0668 - acc: 0.4466 - top5-acc: 0.7625 - val_loss: 2.2047 - val_acc: 0.4240 - val_top5-acc: 0.7330 - lr: 0.0010
# Epoch 38/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.0455 - acc: 0.4511 - top5-acc: 0.7695 - val_loss: 2.2240 - val_acc: 0.4218 - val_top5-acc: 0.7324 - lr: 0.0010
# Epoch 39/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.0452 - acc: 0.4518 - top5-acc: 0.7658 - val_loss: 2.2791 - val_acc: 0.4136 - val_top5-acc: 0.7202 - lr: 0.0010
# Epoch 40/50
# 352/352 [==============================] - 19s 54ms/step - loss: 2.0256 - acc: 0.4561 - top5-acc: 0.7699 - val_loss: 2.2323 - val_acc: 0.4330 - val_top5-acc: 0.7320 - lr: 0.0010
# Epoch 41/50
# 352/352 [==============================] - 19s 53ms/step - loss: 2.0155 - acc: 0.4581 - top5-acc: 0.7735 - val_loss: 2.1622 - val_acc: 0.4356 - val_top5-acc: 0.7410 - lr: 0.0010
# Epoch 42/50
# 352/352 [==============================] - 19s 55ms/step - loss: 2.0074 - acc: 0.4621 - top5-acc: 0.7749 - val_loss: 2.2195 - val_acc: 0.4290 - val_top5-acc: 0.7292 - lr: 0.0010
# Epoch 43/50
# 352/352 [==============================] - 18s 52ms/step - loss: 2.0046 - acc: 0.4588 - top5-acc: 0.7768 - val_loss: 2.1951 - val_acc: 0.4366 - val_top5-acc: 0.7386 - lr: 0.0010
# Epoch 44/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.9938 - acc: 0.4608 - top5-acc: 0.7760 - val_loss: 2.1925 - val_acc: 0.4274 - val_top5-acc: 0.7352 - lr: 0.0010
# Epoch 45/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.9804 - acc: 0.4638 - top5-acc: 0.7811 - val_loss: 2.1690 - val_acc: 0.4356 - val_top5-acc: 0.7438 - lr: 0.0010
# Epoch 46/50
# 352/352 [==============================] - 18s 52ms/step - loss: 1.9770 - acc: 0.4664 - top5-acc: 0.7789 - val_loss: 2.1519 - val_acc: 0.4418 - val_top5-acc: 0.7434 - lr: 0.0010
# Epoch 47/50
# 352/352 [==============================] - 18s 51ms/step - loss: 1.9653 - acc: 0.4697 - top5-acc: 0.7812 - val_loss: 2.2085 - val_acc: 0.4264 - val_top5-acc: 0.7368 - lr: 0.0010
# Epoch 48/50
# 352/352 [==============================] - 19s 53ms/step - loss: 1.9544 - acc: 0.4713 - top5-acc: 0.7856 - val_loss: 2.1682 - val_acc: 0.4436 - val_top5-acc: 0.7358 - lr: 0.0010
# Epoch 49/50
# 352/352 [==============================] - 19s 54ms/step - loss: 1.9499 - acc: 0.4705 - top5-acc: 0.7876 - val_loss: 2.1778 - val_acc: 0.4326 - val_top5-acc: 0.7376 - lr: 0.0010
# Epoch 50/50
# 352/352 [==============================] - 20s 58ms/step - loss: 1.9428 - acc: 0.4741 - top5-acc: 0.7877 - val_loss: 2.1494 - val_acc: 0.4402 - val_top5-acc: 0.7482 - lr: 0.0010
# 313/313 [==============================] - 3s 10ms/step - loss: 2.1053 - acc: 0.4481 - top5-acc: 0.7538
# Test accuracy: 44.81%
# Test top 5 accuracy: 75.38%

# %%
class gMLPLayer(layers.Layer):
    def __init__(self, num_patches, embedding_dim, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)

        self.channel_projection1 = keras.Sequential(
            [
                layers.Dense(units=embedding_dim * 2),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
            ]
        )

        self.channel_projection2 = layers.Dense(units=embedding_dim)

        self.spatial_projection = layers.Dense(
            units=num_patches, bias_initializer="Ones"
        )

        self.normalize1 = layers.LayerNormalization(epsilon=1e-6)
        self.normalize2 = layers.LayerNormalization(epsilon=1e-6)

    def spatial_gating_unit(self, x):
        # Split x along the channel dimensions.
        # Tensors u and v will in th shape of [batch_size, num_patchs, embedding_dim].
        u, v = tf.split(x, num_or_size_splits=2, axis=2)
        # Apply layer normalization.
        v = self.normalize2(v)
        # Apply spatial projection.
        v_channels = tf.linalg.matrix_transpose(v)
        v_projected = self.spatial_projection(v_channels)
        v_projected = tf.linalg.matrix_transpose(v_projected)
        # Apply element-wise multiplication.
        return u * v_projected

    def call(self, inputs):
        # Apply layer normalization.
        x = self.normalize1(inputs)
        # Apply the first channel projection. x_projected shape: [batch_size, num_patches, embedding_dim * 2].
        x_projected = self.channel_projection1(x)
        # Apply the spatial gating unit. x_spatial shape: [batch_size, num_patches, embedding_dim].
        x_spatial = self.spatial_gating_unit(x_projected)
        # Apply the second channel projection. x_projected shape: [batch_size, num_patches, embedding_dim].
        x_projected = self.channel_projection2(x_spatial)
        # Add skip connection.
        return x + x_projected

# %%
gmlp_blocks = keras.Sequential(
    [gMLPLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
learning_rate = 0.003
gmlp_classifier = build_classifier(gmlp_blocks)
history = run_experiment(gmlp_classifier)
# Out:
# Epoch 1/50
# 352/352 [==============================] - 31s 69ms/step - loss: 3.9188 - acc: 0.0999 - top5-acc: 0.2959 - val_loss: 3.5293 - val_acc: 0.1626 - val_top5-acc: 0.4244 - lr: 0.0030
# Epoch 2/50
# 352/352 [==============================] - 23s 66ms/step - loss: 3.4255 - acc: 0.1774 - top5-acc: 0.4418 - val_loss: 3.2418 - val_acc: 0.2174 - val_top5-acc: 0.4956 - lr: 0.0030
# Epoch 3/50
# 338/352 [===========================>..] - ETA: 0s - loss: 3.2190 - acc: 0.2152 - top5-acc: 0.4984
